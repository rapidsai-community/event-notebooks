# %% [markdown]
# #  Fraud Detection use XGBoost
#
# This notebook will demonstate using cuDF for ETL/data cleaning and XGBoost for training a fraud predection model.
# The processing will not use an additional graph processing or GNNs

# %%
# requiered imports
import cudf
import cuml
import xgboost as xgb
import math
# Out:
# /home/brad/anaconda3/envs/cugraph_dev/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ### Data Loading

# %%
# base directoty
base_dir = "./elliptic_bitcoin_dataset/"

# %%
# read the data files
df_features = cudf.read_csv(base_dir + 'elliptic_txs_features.csv', header=None)
df_classes  = cudf.read_csv(base_dir + "elliptic_txs_classes.csv")

# we do not need the edge dataset for this workflow
# df_edges    = cudf.read_csv(base_dir + "elliptic_txs_edgelist.csv")

# %% [markdown]
# ### Let's look at the Class dataset

# %%
df_classes.head(5)
# Out:
#         txId    class
# 0  230425980  unknown
# 1    5530458  unknown
# 2  232022460  unknown
# 3  232438397        2
# 4  230460314  unknown

# %% [markdown]
# The documentation list class values as:</br>
# 1 = illicit</br>
# 2 = licit</br>
# unknown = unknown </br>
# </br>
# It would be nice if the "class" column as an integer value and not string, so let's convert "unlnown" to 0

# %%
# replace the value and set the type to int32
df_classes['class'] = df_classes['class'].replace("unknown", "0").astype('int32')

# %%
df_classes.head(5)
# Out:
#         txId  class
# 0  230425980      0
# 1    5530458      0
# 2  232022460      0
# 3  232438397      2
# 4  230460314      0

# %% [markdown]
# ### merge the classes into the feature dataset
# but we might need to adjust the dataframe some

# %%
df_features.head(5)
# Out:
#            0  1         2         3         4          5         6         7  \
# 0  230425980  1 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875 -0.113002
# 1    5530458  1 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875 -0.113002
# 2  232022460  1 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875 -0.113002
# 3  232438397  1  0.163054  1.963790 -0.646376  12.409294 -0.063725  9.782742
# 4  230460314  1  1.011523 -0.081127 -1.201369   1.153668  0.333276  1.312656
#
#            8         9  ...       157       158       159       160       161  \
# 0  -0.061584 -0.162097  ... -0.562153 -0.600999  1.461330  1.461369  0.018279
# 1  -0.061584 -0.162112  ...  0.947382  0.673103 -0.979074 -0.978556  0.018279
# 2  -0.061584 -0.162749  ...  0.670883  0.439728 -0.979074 -0.978556 -0.098889
# 3  12.414558 -0.163645  ... -0.577099 -0.613614  0.241128  0.241406  1.072793
# 4  -0.061584 -0.163523  ... -0.511871 -0.400422  0.517257  0.579382  0.018279
#
#         162       163       164       165       166
# 0 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 1 -0.087490 -0.131155 -0.097524 -0.120613 -0.119792
# 2 -0.106715 -0.131155 -0.183671 -0.120613 -0.119792
# 3  0.085530 -0.131155  0.677799 -0.120613 -0.119792
# 4  0.277775  0.326394  1.293750  0.178136  0.179117
#
# [5 rows x 167 columns]

# %%
# change the column 0 name to be txId to match the classes dataframe
df_features.rename(columns={'0' : 'txId'}, inplace=True)

# %%
# drop "aggregated features" 
df_features = df_features.iloc[:, 0:95]

# %%
df_features.head(2)
# Out:
#         txId  1         2         3         4        5         6         7  \
# 0  230425980  1 -0.171469 -0.184668 -1.201369 -0.12197 -0.043875 -0.113002
# 1    5530458  1 -0.171484 -0.184668 -1.201369 -0.12197 -0.043875 -0.113002
#
#           8         9  ...        85        86        87        88        89  \
# 0 -0.061584 -0.162097  ... -0.255111 -0.259194  1.125590  1.128038 -0.293773
# 1 -0.061584 -0.162112  ... -0.255168 -0.259251 -0.187191 -0.185274 -0.293692
#
#          90        91        92        93        94
# 0 -0.159732  0.034039 -0.183816  1.135523  1.135279
# 1 -0.760700 -0.692777 -0.719789 -1.084907 -1.084845
#
# [2 rows x 95 columns]

# %%
# merging dataframes
df_merge = df_features.merge(df_classes, how='left', on='txId')

# %% [markdown]
# ### Pull out the labeled data into groups for training, validating, and testing

# %%
classified   = df_merge.loc[df_merge['class'] != 0]
unclassified = df_merge.loc[df_merge['class'] == 0]

# %%
classified.head(5)
# Out:
#          txId  1         2         3         4         5         6         7  \
# 6     8988238  6 -0.170733 -0.184668 -1.201369  0.103143 -0.063725  0.138585
# 18  230424162  1 -0.169956 -0.184668 -1.201369 -0.121970 -0.043875 -0.113002
# 19  232354200  1 -0.172157 -0.184479  1.018602 -0.046932 -0.063725 -0.029140
# 22  230473471  1 -0.171958 -0.184668 -1.201369 -0.121970 -0.043875 -0.113002
# 23  234472313  1 -0.171507 -0.184668 -1.201369  0.028105 -0.024025  0.054722
#
#            8         9  ...        86        87        88        89        90  \
# 6  -0.061584 -0.163342  ...  0.125159 -0.187191 -0.185274 -0.156403 -0.711518
# 18 -0.061584 -0.160548  ...  1.354381  1.125590  1.128038  3.114411  2.700735
# 19 -0.061584 -0.163645  ... -0.255907 -0.187191 -0.185274  0.335654 -0.530923
# 22 -0.061584 -0.162597  ... -0.256506  1.125590  1.128038 -0.293649  3.179307
# 23 -0.061584 -0.163638  ... -0.259251 -0.187191 -0.185274 -0.292015 -0.730377
#
#           91        92        93        94  class
# 6  -0.694235 -0.630983  0.025308  0.025217      2
# 18  1.980603  3.483066  1.135523  1.135279      2
# 19 -0.694235 -0.308840  0.025308  0.025217      2
# 22  4.072051  2.794295  1.135523  1.135279      2
# 23 -0.664210 -0.700770 -0.007457 -0.529814      2
#
# [5 rows x 96 columns]

# %%
# reset the index 
classified.reset_index(inplace=True, drop=True)

# %%
classified.head(5)
# Out:
#         txId  1         2         3         4         5         6         7  \
# 0    8988238  6 -0.170733 -0.184668 -1.201369  0.103143 -0.063725  0.138585
# 1  230424162  1 -0.169956 -0.184668 -1.201369 -0.121970 -0.043875 -0.113002
# 2  232354200  1 -0.172157 -0.184479  1.018602 -0.046932 -0.063725 -0.029140
# 3  230473471  1 -0.171958 -0.184668 -1.201369 -0.121970 -0.043875 -0.113002
# 4  234472313  1 -0.171507 -0.184668 -1.201369  0.028105 -0.024025  0.054722
#
#           8         9  ...        86        87        88        89        90  \
# 0 -0.061584 -0.163342  ...  0.125159 -0.187191 -0.185274 -0.156403 -0.711518
# 1 -0.061584 -0.160548  ...  1.354381  1.125590  1.128038  3.114411  2.700735
# 2 -0.061584 -0.163645  ... -0.255907 -0.187191 -0.185274  0.335654 -0.530923
# 3 -0.061584 -0.162597  ... -0.256506  1.125590  1.128038 -0.293649  3.179307
# 4 -0.061584 -0.163638  ... -0.259251 -0.187191 -0.185274 -0.292015 -0.730377
#
#          91        92        93        94  class
# 0 -0.694235 -0.630983  0.025308  0.025217      2
# 1  1.980603  3.483066  1.135523  1.135279      2
# 2 -0.694235 -0.308840  0.025308  0.025217      2
# 3  4.072051  2.794295  1.135523  1.135279      2
# 4 -0.664210 -0.700770 -0.007457 -0.529814      2
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Split data into training and validation sets
# cuML has a nice function for doing this

# %%
X_train, X_test = cuml.model_selection.train_test_split(classified, test_size=0.3, random_state=0)

# %%
X_train.reset_index(inplace=True, drop=True)
X_test.reset_index(inplace=True, drop=True)

# %%
X_train['class'].value_counts()
# Out:
# 2    29405
# 1     3190
# Name: class, dtype: int32

# %%
X_test['class'].value_counts()
# Out:
# 2    12614
# 1     1355
# Name: class, dtype: int32

# %%
# Pull out the class column and then drop from th etraining set
Y_train = X_train[['class']]
X_train.drop(columns=['class'], inplace=True)

# %%
Y_test = X_test[['class']]
X_test.drop(columns=['class'], inplace=True)

# %% [markdown]
# ### Use XGBoost

# %%
# Create a DMatrix
dtrain = xgb.DMatrix(X_train, Y_train)

# %%
# Train XGBoost
params = {
    'learning_rate'  : 0.3,
    'max_depth'      : 8,
    'objective'      : 'reg:squarederror',
    'subsample'      : 0.6,
    'gamma'          : 1,
    'silent'         : True,
    'verbose_eval'   : True,
    'tree_method'    :'gpu_hist'
}

# %%
trained_model = xgb.train(params, dtrain)
# Out:
# [13:42:51] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117836726/work/src/learner.cc:576:
# Parameters: { "silent", "verbose_eval" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
# test
dtest = xgb.DMatrix(X_test, Y_test)

# %%
Y_test['prediction'] = trained_model.predict(dtest)

# %%
Y_test['squared_error'] = (Y_test['prediction'] - Y_test['class'])**2

# %%
Y_test.head()
# Out:
#    class  prediction  squared_error
# 0      2    1.954282       0.002090
# 1      2    1.950591       0.002441
# 2      2    1.912535       0.007650
# 3      2    1.933244       0.004456
# 4      2    1.955077       0.002018

# %%
Y_test[Y_test['class'] == 1].head()
# Out:
#     class  prediction  squared_error
# 10      1    1.861766       0.742640
# 19      1    1.113765       0.012942
# 27      1    1.217391       0.047259
# 39      1    0.995994       0.000016
# 51      1    0.984595       0.000237

# %%
# compute the actual RMSE over the full test set
RMSE = Y_test['squared_error'].mean()
math.sqrt(RMSE)
# Out:
# 0.12961256075749394

# %%
Y_test[Y_test['prediction'] > 1.5]['class'].value_counts()
# Out:
# 2    12595
# 1      229
# Name: class, dtype: int32
