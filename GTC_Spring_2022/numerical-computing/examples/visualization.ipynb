# %% [markdown]
# # **Visualization**

# %% [markdown]
# For a more intuitive understanding of the sample problem, we generate a visualization representing the first ```n_steps``` of our dynamic system comprising changing observations and dynamic reference points.

# %%
from src.visualize import multi_plot

# %% [markdown]
# Define constants for the size problem to visualize.
#
# Note - matplotlib + our screen real estate will constrain the size of problem we can intuitively visualize -- suggested values are:
#
# ```N_OBS = 16384```<br>
# ```N_REF = 128```

# %%
N_OBS = 16384
N_REF = 128

# %% [markdown]
# Colored regions represent distinct reference points. Points within boundaries have a nearest neighbor represented by the colored region that contains it.
#
# Note - Because of limited colors in the colormap, colors may be repeated for different regions.

# %%
multi_plot(N_OBS, N_REF)

# %% [markdown]
# <br>
# <div align="left"><h2><b>Please Restart the Kernel<b></h2></div>

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
